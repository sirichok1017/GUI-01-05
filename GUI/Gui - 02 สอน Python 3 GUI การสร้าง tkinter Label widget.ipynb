# %% [markdown]
# # สอน Python GUI การสร้าง tkinter Label widget

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('Xu_buKCtd_M')

# %% [markdown]
# ## รูปแบบการเขียน tkinter Label widget
#
# * Label(root, text="ตัวอักษร",fg="สี", bg="สี"",wraplength=700).pack(fill=X)
#
#
# * text - ตัวอักษรที่ต้องการเขียน
# * fg - foreground ต้องการใส่สีใน foreground
# * bg - background ต้องการใส่สีใน background
# * wraplength - ขนาด Screen Unit
# * .pack() - กำหนดตัวอักษรให้ชิดซ้าย ชิดขวา หรือตรงกลาง
#     * .pack(anchor=W) - ต้องการให้ตัวอักษรชิดซ้าย
#     * .pack(anchor=E) - ต้องการให้ตัวอักษรชิดขวา
#     * .pack(fill=X) - ต้องการให้ตัวอักษรอยู่ตรงกลาง

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)
Label(root, text="apple").pack() #สร้าง Label widget "apple"

root.mainloop() #คำสั่งแสดงผล GUI

#ถ้า Run จะได้ Windows ขึ้นมาใน Label จะมีคำว่า "apple" อยู่ตรงกลาง

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)
root.option_add("*Font", "consolas 25") #Font ทั้งหมด widget เป็น consolas ขนาด 25
Label(root, text="apple").pack() #สร้าง Label widget "apple"

root.mainloop() #คำสั่งแสดงผล GUI

#ถ้า Run คำว่า "apple" จะมีขนาดที่ใหญ่ขึ้นจากเดิม

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#foreground=fg background=bg ใส่สีที่ต้องการเปลี่ยน foreground และ background
Label(root, text="apple").pack() 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack()
Label(root, text="apple", fg="red", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run จะมี "apple" 4คำ จะมีสีตัวอักษรืและพื้นหลังตามที่เรากำหนด

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#foreground=fg background=bg ใส่สีที่ต้องการเปลี่ยน foreground และ background
Label(root, text="apple").pack() 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack()
Label(root, text="apple", fg="red", bg="green").pack()
Label(root, text="banana", fg="red", bg="green").pack()
Label(root, text="coconut", fg="red", bg="green").pack()
Label(root, text="strawberry", fg="red", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run จะสังเกตว่า ตัวอักษรจะอยู่ Center ทุกตัว

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#เราต้องการให้ตัวอักษรชิดซ้าย โดยการเพิ่ม .pack() เป็น .pack(anchor=W)
Label(root, text="apple").pack() 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="red", bg="green").pack()
Label(root, text="banana", fg="red", bg="green").pack()
Label(root, text="coconut", fg="red", bg="green").pack()
Label(root, text="strawberry", fg="red", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run "apple" คำที่ 3 ที่เพิ่ม .pack(anchor=W) จะชิดซ้ายเพียงตัวเดียว

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#เราต้องการให้ตัวอักษรชิดซ้าย โดยการเพิ่ม .pack() เป็น .pack(anchor=W)
#เราต้องการให้ตัวอักษรชิดขวา โดยการเพิ่ม .pack() เป็น .pack(anchor=E)
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="red", bg="green").pack()
Label(root, text="banana", fg="red", bg="green").pack()
Label(root, text="coconut", fg="red", bg="green").pack()
Label(root, text="strawberry", fg="red", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run "apple" คำที่ 1 ที่เพิ่ม .pack(anchor=E) จะชิดขวาเพียงตัวเดียว

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#เราสามารถเพิ่มขนาดความกว้างตัวอักษร โดยการเพิ่ม width=
#คำไหนที่ยาวสุดจะถูกยึดเป็น Center (ในที่นี้คือ strawberry)
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="red", bg="green").pack()
Label(root, text="banana", bg="yellow", width=15).pack()
Label(root, text="coconut", fg="red", bg="green").pack()
Label(root, text="strawberry", fg="red", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run เราจะเห็นว่า "banana" มี background เป็นสีเหลือง และมีขนาดความกว้างตัวอักษรเพิ่มขึ้นเป็น 15

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#เราต้องการให้ตัวอักษรอยู่ตรงกลางมากที่สุด โดยการเพิ่ม .pack() เป็น .pack(fill=X)
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="red", bg="green").pack()
Label(root, text="banana", bg="yellow", width=15).pack()
Label(root, text="coconut", bg="green").pack(fill=X)
Label(root, text="strawberry", fg="red", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run จะเห็นได้ว่า "coconut" จะอยู่ตรงกลางมากขึ้น

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#เราต้องการเพิ่มช่องว่างระหว่างบรรทัด โดยการเพิ่ม .pack() เป็น .pack(pady=10)
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="red", bg="green").pack(pady=10)
Label(root, text="banana", bg="yellow", width=15).pack()
Label(root, text="coconut", bg="green").pack(fill=X)
Label(root, text="strawberry", fg="red", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run จะเห็นได้ว่า "apple" คำที่ 4 จะมีช่องว่างระหว่างบรรทัด

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#เราใส่ตัวอักษรเป็นภาษาไทยได้
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="green").pack(pady=10)
Label(root, text="banana", bg="yellow", width=15).pack()
Label(root, text="coconut", bg="green").pack(fill=X)
Label(root, text="strawberry", fg="red", bg="green").pack()
Label(root, text="แผ่นดินของเรา", bg="green").pack()

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run จะเห็นได้ว่า "แผ่นดินของเรา" สามารถใส่ภาษาไทยใน widget ได้

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#เราสามารถใส่ \n เป็นสัญลักษณ์ การขึ้นบรรทัดใหม่
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="green").pack(pady=10)
Label(root, text="banana", bg="yellow", width=15).pack()
Label(root, text="coconut", bg="green").pack(fill=X)
Label(root, text="strawberry", fg="red", bg="green").pack()
Label(root, text="แผ่นดินของเรา", bg="deep sky blue").pack(fill=X)
Label(root, text="green\ntea", bg="green").pack(fill=X)

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run จะเห็นได้ว่า "green\ntea" แยกออกมาตัวละบรรทัด

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="green").pack(pady=10)
Label(root, text="banana", bg="yellow", width=15).pack()
Label(root, text="coconut", bg="green").pack(fill=X)
Label(root, text="strawberry", fg="red", bg="green").pack()
Label(root, text="แผ่นดินของเรา", bg="deep sky blue").pack(fill=X)
Label(root, text="green\ntea", bg="green").pack(fill=X)
Label(root, text="Happiness is when what you think, what you say, and what you do are in harmony.",bg="gold").pack(fill=X)

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run จะเห็นได้ว่า "Happiness is when what you think, what you say, and what you do are in harmony." เป็นประโยคที่ยาวอาจจะแสดงผลได้ไม่ครบ

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#วิธีการแก้ ประโยคที่ยาว โดยการใช้ wraplength=400 (400 เป็น Screen Unit)
Label(root, text="apple").pack(anchor=E) 
Label(root, text="apple", fg="red").pack()
Label(root, text="apple", bg="green").pack(anchor=W)
Label(root, text="apple", fg="green").pack(pady=10)
Label(root, text="banana", bg="yellow", width=15).pack()
Label(root, text="coconut", bg="green").pack(fill=X)
Label(root, text="strawberry", fg="red", bg="green").pack()
Label(root, text="แผ่นดินของเรา", bg="deep sky blue").pack(fill=X)
Label(root, text="green\ntea", bg="green").pack(fill=X)
Label(root, text="Happiness is when what you think, what you say, and what you do are in harmony.",bg="gold").pack(fill=X)
Label(root,text="Happiness is when what you think, what you say, and what you do are in harmony.",bg="orange", wraplength=400).pack(fill=X)

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run แล้วเปรียบเทียบจะเห็นได้ว่า "Happiness is ..." อันที่มี wraplength=400 จะถูกแบ่งช่วงตัวอักษร ทำให้แสดงผลได้ครบ

# %%
from tkinter import * #โหลดโมดูล tkinter

root = Tk() #สร้างออบเจ็ค ชื่อ root (ชื่ออะไรก็ได้)

#Font ทั้งหมด widget เป็น consolas ขนาด 25
root.option_add("*Font", "consolas 25") 

#สร้าง Label widget "apple" 
#วิธีการแก้ ประโยคที่ยาว โดยการใช้ wraplength=400 (400 เป็น Screen Unit)
#wraplength สามารถใชร่วมกับคำสั่งอื่นได้
#wraplength กับ \n เป็นสัญลักษณ์ การขึ้นบรรทัดใหม่
#wraplength กับ justify=LEFT justify=RIGHT ต้องการให้ชิดซ้าย ชิดขวา

Label(root, text="Happiness is when what you think, what you say, and what you do are in harmony.",bg="gold").pack(fill=X)
Label(root, text="Happiness is when what you think, what you say, and what you do are in harmony.",bg="orange", wraplength=400, justify=RIGHT).pack(fill=X)
Label(root, text="Happiness is when what you think, what you say, and what you do are in harmony.",bg="deep sky blue", wraplength=700, justify=LEFT).pack(fill=X)
Label(root, text="Happiness is when what you think, what you say, and what you do are in harmony.\n\nMahatma Gandhi",bg="hot pink", wraplength=700).pack(fill=X)

#คำสั่งแสดงผล GUI
root.mainloop() 

#ถ้า Run แล้วจะเห็นว่า "Happiness is ..." สามารถทำได้หลายรูปแบบแล้วแต่เราต้องการกำหนด
